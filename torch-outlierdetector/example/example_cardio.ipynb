# %%
from .. import auto_encoder
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-3be262934927> in <module>
# ----> 1 from .. import auto_encoder
#
# ValueError: attempted relative import beyond top-level package

# %%
print(__name__)
# Out:
# __main__

# %%
import sys
sys.path
# Out:
# ['F:\\github_project\\torchAEOD\\torchAEOD\\torch-outlierdetector\\example',
#  'F:\\github_project\\torchAEOD\\torchAEOD',
#  'C:\\Users\\xfypk\\Anaconda3\\python37.zip',
#  'C:\\Users\\xfypk\\Anaconda3\\DLLs',
#  'C:\\Users\\xfypk\\Anaconda3\\lib',
#  'C:\\Users\\xfypk\\Anaconda3',
#  '',
#  'C:\\Users\\xfypk\\AppData\\Roaming\\Python\\Python37\\site-packages',
#  'C:\\Users\\xfypk\\Anaconda3\\lib\\site-packages',
#  'C:\\Users\\xfypk\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\xfypk\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\xfypk\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\xfypk\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\xfypk\\.ipython']

# %%
from scipy.io import loadmat
df = loadmat('../data/cardio.mat')

# %%
y.detach().numpy()
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [1.],
#        [1.],
#        [1.]], dtype=float32)

# %%
import torch
X = torch.from_numpy(df['X']).float()
y = torch.from_numpy(df['y']).float()

# %%
y
# Out:
# tensor([[0.],
#         [0.],
#         [0.],
#         ...,
#         [1.],
#         [1.],
#         [1.]])

# %%
a = torch_AEOD([12,6,12],['sigmoid','relu','relu','relu'])

# %%
a.train(X, 10,200,0.05)
# Out:
# [Linear(in_features=21, out_features=12, bias=True), Sigmoid(), Linear(in_features=12, out_features=6, bias=True), ReLU()]
# [Linear(in_features=6, out_features=12, bias=True), ReLU(), Linear(in_features=12, out_features=21, bias=True), ReLU()]
# epoch : 1/10, loss = 0.219180
# epoch : 2/10, loss = 0.249789
# epoch : 3/10, loss = 0.203499
# epoch : 4/10, loss = 0.238101
# epoch : 5/10, loss = 0.131133
# epoch : 6/10, loss = 0.272135
# epoch : 7/10, loss = 0.138085
# epoch : 8/10, loss = 0.190445
# epoch : 9/10, loss = 0.148503
# epoch : 10/10, loss = 0.175900

# %%
a.decision_function(X)
# Out:
# [0.47769165,
#  0.5958211,
#  0.8206887,
#  0.7547303,
#  0.32418823,
#  0.55809224,
#  0.5809383,
#  0.5589366,
#  0.8232656,
#  0.5689322,
#  0.48945984,
#  0.8883752,
#  2.5569463,
#  1.5190428,
#  3.101106,
#  0.94330925,
#  1.1668801,
#  0.8186561,
#  1.3371702,
#  1.1164286,
#  1.0789323,
#  1.2626451,
#  0.78696895,
#  0.7390582,
#  0.90652674,
#  0.51039773,
#  0.73593664,
#  1.4561093,
#  1.6165831,
#  1.947463,
#  1.8368489,
#  2.983551,
#  1.2751615,
#  1.300572,
#  2.0815623,
#  0.96683985,
#  0.83667135,
#  0.44831833,
#  0.5210746,
#  0.6533992,
#  0.6034094,
#  0.3180368,
#  0.41624445,
#  0.96022767,
#  0.631818,
#  0.4270361,
#  0.4270361,
#  0.71912646,
#  0.73922664,
#  0.5498755,
#  0.53065664,
#  0.4550928,
#  0.48977295,
#  0.5323315,
#  0.5709159,
#  0.92977893,
#  0.5734441,
#  0.70608497,
#  0.60483444,
#  0.97925377,
#  1.0988566,
#  1.1230198,
#  0.7829876,
#  0.56868106,
#  0.6449361,
#  0.9280278,
#  0.7375521,
#  0.25534034,
#  0.36796728,
# ...

# %%
tpr, fpr, threshold = a.roc_curve(X,y)

# %%
import matplotlib.pyplot as plt
plt.plot(tpr,fpr)
